# %% [markdown]
# ## Problema 4: Pseudocódigo, Calculador de perfil. ##

# %%
edad = int(input("Ingresa tu edad: "))
gusta_musica_urbana = (input("¿Te gusta la musica urbana? Escribe si o no: "))
def evaluar_usuario (edad_usuario, gusto_usuario):

 if edad_usuario>=18 and gusto_usuario in ("si", "sí", "Sí", "Si", "SI", "SÍ"):
  print("Eres mayor de edad y te gusta la musica urbana")

 else:
  print("No te gusta la música urbana o no eres mayor de edad :c")

evaluar_usuario(edad, gusta_musica_urbana)
